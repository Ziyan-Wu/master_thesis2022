# %%
# %run ../../processed/myfuncs.ipynb

# %%
df = gpd.read_file('output/df_zall.gpkg')#.to_crs(epsg=7415)
print(len(df))
df.head()
# Out:
# 73
#         gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0  11985008     1.2800     6.9551     7.0083     8.3438     646
# 1  11985087    -0.7194     1.7421     1.9457     2.3112     646
# 2   3149890     2.0670    10.2948    10.6660    11.2590    2311
# 3  11989276     1.1740     5.1230     5.1836     6.6129     646
# 4  11989554     0.8943     3.6225     3.8201     4.4390     646
#
#    construction_year  h_maaiveld  intersection_cnt  idw_100m  g_diff  r_50th  \
# 0               2018       0.377                 4   -0.1099  0.4869  6.9969
# 1               2009      -0.778                 7   -1.0722  0.2942  2.2928
# 2               2019       1.704                 1    0.4771  1.2269  8.0882
# 3               2012       1.197                 1    1.0488  0.1482  5.2199
# 4               2012       0.396                12    1.1669  0.7709  4.9229
#
#    r50p50  bh_real      bh  bh_diff  \
# 0  0.0418   6.5781  7.1068   0.5287
# ...

# %%
df
# Out:
#          gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0   11985008     1.2800     6.9551     7.0083     8.3438     646
# 1   11985087    -0.7194     1.7421     1.9457     2.3112     646
# 2    3149890     2.0670    10.2948    10.6660    11.2590    2311
# 3   11989276     1.1740     5.1230     5.1836     6.6129     646
# 4   11989554     0.8943     3.6225     3.8201     4.4390     646
# ..       ...        ...        ...        ...        ...     ...
# 68  23889338     0.5556     7.2830     8.3114     9.9729    2310
# 69  11988649     1.3877     3.6288     3.6490     3.7171     646
# 70  11988668     1.1381     3.7444     3.9261     4.5374     646
# 71  11988999     1.3464    15.2741    15.2934    16.2058     646
# 72  11989079     0.6394     6.4916     7.7621    10.0783     646
#
#     construction_year  h_maaiveld  intersection_cnt  idw_100m  g_diff  \
# 0                2018       0.377                 4   -0.1099  0.4869
# ...

# %%
df_pts432 = gpd.read_file('output/icesat_c432.gpkg')#.to_crs(epsg=7415)
print(len(df_pts432))
df_pts432.head()
# Out:
# 86286
#                x              y          z                    t  confidence  \
# 0  254071.326387  578582.206190   3.009821  2018-11-09T02:04:49           4
# 1  254063.906737  578494.435303  14.250419  2018-11-09T02:04:49           2
# 2  254060.782652  578454.799000   2.422196  2018-11-09T02:04:49           4
# 3  254059.274980  578437.059569   2.030847  2018-11-09T02:04:49           4
# 4  254059.095300  578434.931556   1.914078  2018-11-09T02:04:49           4
#
#   track   power                                geometry
# 0  gt1r  strong   POINT Z (254071.326 578582.206 3.010)
# 1  gt1r  strong  POINT Z (254063.907 578494.435 14.250)
# 2  gt1r  strong   POINT Z (254060.783 578454.799 2.422)
# 3  gt1r  strong   POINT Z (254059.275 578437.060 2.031)
# 4  gt1r  strong   POINT Z (254059.095 578434.932 1.914)

# %%
df_cnt432 = gpd.read_file('output/df_cnt432.gpkg')
print(len(df_cnt432))
df_cnt432.head()
# Out:
# 107
#         gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0  11985008   1.279962   6.955098   7.008342   8.343763     646
# 1  11985087  -0.719438   1.742089   1.945698   2.311170     646
# 2   3149890   2.067034  10.294793  10.665979  11.259021    2311
# 3  11989276   1.173986   5.123024   5.183640   6.612879     646
# 4  11989346   0.865801   4.903423   6.291296   8.825522     646
#
#    construction_year  h_maaiveld  intersection_cnt  \
# 0               2018       0.377                 4
# 1               2009      -0.778                 7
# 2               2019       1.704                 1
# 3               2012       1.197                 1
# 4               2013       0.825                 1
#
#                                             geometry
# 0  MULTIPOLYGON (((253534.502 576874.344, 253533....
# 1  MULTIPOLYGON (((253392.410 575337.339, 253392....
# 2  MULTIPOLYGON (((252324.335 575914.840, 252324....
# ...

# %%
df_pts432_clean = gpd.read_file('output/icesat432_bplot.gpkg')#.to_crs(epsg=7415)
print(len(df_pts432_clean))
df_pts432_clean.head()
# Out:
# 81186
#                x              y         z                    t  confidence  \
# 0  254071.326387  578582.206190  3.009821  2018-11-09T02:04:49           4
# 1  254060.782652  578454.799000  2.422196  2018-11-09T02:04:49           4
# 2  254059.274980  578437.059569  2.030847  2018-11-09T02:04:49           4
# 3  254059.095300  578434.931556  1.914078  2018-11-09T02:04:49           4
# 4  254054.206803  578377.525711  2.119978  2018-11-09T02:04:49           4
#
#   track   power                               geometry
# 0  gt1r  strong  POINT Z (254071.326 578582.206 3.010)
# 1  gt1r  strong  POINT Z (254060.783 578454.799 2.422)
# 2  gt1r  strong  POINT Z (254059.275 578437.060 2.031)
# 3  gt1r  strong  POINT Z (254059.095 578434.932 1.914)
# 4  gt1r  strong  POINT Z (254054.207 578377.526 2.120)

# %%
df
# Out:
#          gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0   11985008     1.2800     6.9551     7.0083     8.3438     646
# 1   11985087    -0.7194     1.7421     1.9457     2.3112     646
# 2    3149890     2.0670    10.2948    10.6660    11.2590    2311
# 3   11989276     1.1740     5.1230     5.1836     6.6129     646
# 4   11989554     0.8943     3.6225     3.8201     4.4390     646
# ..       ...        ...        ...        ...        ...     ...
# 68  23889338     0.5556     7.2830     8.3114     9.9729    2310
# 69  11988649     1.3877     3.6288     3.6490     3.7171     646
# 70  11988668     1.1381     3.7444     3.9261     4.5374     646
# 71  11988999     1.3464    15.2741    15.2934    16.2058     646
# 72  11989079     0.6394     6.4916     7.7621    10.0783     646
#
#     construction_year  h_maaiveld  intersection_cnt  idw_100m  g_diff  \
# 0                2018       0.377                 4   -0.1099  0.4869
# ...

# %%
diandian(df,save=True,name='z_diandian')
# Out:
# save:  z_diandian

# %%
overlaphis(df, save = True, name ='z_overlaphis')
# Out:
# save:  z_overlaphis

# %%
sns.kdeplot(df['idw_100m'],label='calculated')
sns.kdeplot(df['h_maaiveld'],label='reference')
# plt.ylim([-0.01,1.4])
plt.xlabel('Elevation (m)')
plt.legend()

# %%
sns.kdeplot(df['r_50th'],label='calculated')
sns.kdeplot(df['h_dak_50p'],label='reference')
plt.ylim([-0.001,0.21])
plt.xlabel('Elevation (m)')
plt.legend()

# %%
fig, ((ax1, ax2, ax3)) = plt.subplots(1, 3, figsize=(13,3.5))
# fig.delaxes(ax4)
sns.kdeplot(df['h_maaiveld'],ax=ax1,label='reference')
sns.kdeplot(df['idw_100m'],ax=ax1,label='calculated')
ax1.set_ylim([-0.02,0.8])
ax1.set_title('ground')
ax1.legend(loc=0)
ax1.set_xlabel("Elevation(m)")

sns.kdeplot(df['h_dak_50p'],ax=ax2,label='reference')
sns.kdeplot(df['r_50th'],ax=ax2,label='calculated')
ax2.set_ylim([-0.01,0.22])
ax2.set_title('roof')
ax2.legend(loc=0)
ax2.set_xlabel("Elevation(m)")
ax2.set_ylabel("")

sns.kdeplot(df['bh_real'],ax=ax3,label='reference')
sns.kdeplot(df['bh'],ax=ax3,label='calculated')
ax3.set_ylim([-0.01,0.25])
ax3.set_title('building height')
ax3.legend(loc=0)
ax3.set_xlabel("Height(m)")
ax3.set_ylabel("")

plt.savefig('for_report/'+ 'z_kde', dpi=500,bbox_inches='tight') # ,dpi=600

# %%
l_gbs, l_gsb = get_10gids(df, "g_diff")
l_rbs, l_rsb = get_10gids(df, "r50p50")
l_bbs, l_bsb = get_10gids(df, "bh_diff")

# %% [markdown]
# ## ROOF

# %%
plot_10gids(l_rsb, df, df_pts432, 'r', save=True, name='z_rsb')
# Out:
# save  z_rsb

# %%
plot_10gids(l_rbs, df, df_pts432, 'r', save=True, name='z_rbs')
# Out:
# save  z_rbs

# %%
show_one_gid(11986197, df_cnt432, df_pts432)
# Out:
#         gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0  11986197   1.420278   4.352066    6.06089   9.431504     646
#
#    construction_year  h_maaiveld  intersection_cnt  \
# 0               1993         1.4                 1
#
#                                             geometry
# 0  MULTIPOLYGON (((253404.932 576287.015, 253399....
# number of points inside: 2

# %%
df[df['gid'] == 11986197]
# Out:
#          gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 33  11986197     1.4203     4.3521     6.0609     9.4315     646
#
#     construction_year  h_maaiveld  intersection_cnt  idw_100m  g_diff  r_50th  \
# 33               1993         1.4                 1    1.1808  0.2192  8.6248
#
#     r50p50  bh_real     bh  bh_diff  \
# 33  4.2728   2.9521  7.444   4.4919
#
#                                              geometry
# 33  MULTIPOLYGON (((253404.932 576287.015, 253399....

# %%
show_one_gid(11986159, df_cnt432, df_pts432)
# Out:
#         gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0  11986159   1.049931   4.449802   6.120073   9.072414     646
#
#    construction_year  h_maaiveld  intersection_cnt  \
# 0               1990        0.84                13
#
#                                             geometry
# 0  MULTIPOLYGON (((253299.560 576379.321, 253299....
# number of points inside: 17

# %%
show_one_gid(11985318, df_cnt432, df_pts432)
# Out:
#         gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0  11985318   1.962809   9.189263  11.064235  12.450529     646
#
#    construction_year  h_maaiveld  intersection_cnt  \
# 0               1900       1.925                13
#
#                                             geometry
# 0  MULTIPOLYGON (((253370.709 576118.779, 253370....
# number of points inside: 23

# %%
show_one_gid(11986211, df_cnt432, df_pts432)
# Out:
#         gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0  11986211   1.499979   4.738913   6.112331   8.940039     646
#
#    construction_year  h_maaiveld  intersection_cnt  \
# 0               1996       1.463                16
#
#                                             geometry
# 0  MULTIPOLYGON (((253292.183 576194.593, 253292....
# number of points inside: 26

# %%
show_one_gid(11989079, df_cnt432, df_pts432)
# Out:
#         gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0  11989079   0.639444   6.491582   7.762076  10.078319     646
#
#    construction_year  h_maaiveld  intersection_cnt  \
# 0               2011         0.6                 8
#
#                                             geometry
# 0  MULTIPOLYGON (((255231.527 578594.685, 255231....
# number of points inside: 10

# %%
show_one_gid(23889267, df_cnt432, df_pts432)
# Out:
#         gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0  23889267   0.742706   5.592555    6.97121   9.050683    2310
#
#    construction_year  h_maaiveld  intersection_cnt  \
# 0               1986       0.717                 5
#
#                                             geometry
# 0  MULTIPOLYGON (((251055.720 577464.368, 251054....
# number of points inside: 7

# %%
show_one_gid(11988668, df_cnt432, df_pts432)
# Out:
#         gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0  11988668   1.138118   3.744351   3.926082   4.537435     646
#
#    construction_year  h_maaiveld  intersection_cnt  \
# 0               1968       1.105                 8
#
#                                             geometry
# 0  MULTIPOLYGON (((253410.228 575858.168, 253411....
# number of points inside: 10

# %%
show_one_gid(3149890, df_cnt432, df_pts432)
# Out:
#        gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0  3149890   2.067034  10.294793  10.665979  11.259021    2311
#
#    construction_year  h_maaiveld  intersection_cnt  \
# 0               2019       1.704                 1
#
#                                             geometry
# 0  MULTIPOLYGON (((252324.335 575914.840, 252324....
# number of points inside: 9

# %%
show_one_gid(11985341, df_cnt432, df_pts432)
# Out:
#         gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0  11985341    1.84717   6.292341   7.316969   9.115312     646
#
#    construction_year  h_maaiveld  intersection_cnt  \
# 0               1986       1.866                15
#
#                                             geometry
# 0  MULTIPOLYGON (((253269.386 576026.653, 253271....
# number of points inside: 17

# %%
show_one_gid(23889219, df_cnt432, df_pts432)
# Out:
#         gid  h_dak_min  h_dak_50p  h_dak_70p  h_dak_max tile_id  \
# 0  23889219    1.22894   5.781313   6.832344   8.656935    2310
#
#    construction_year  h_maaiveld  intersection_cnt  \
# 0               1900         1.1                 1
#
#                                             geometry
# 0  MULTIPOLYGON (((252127.894 577546.685, 252128....
# number of points inside: 2

# %% [markdown]
# ## ground

# %%
plot_10gids(l_gbs, df, df_pts432, 'g', save=True, name='z_gbs')
# Out:
# save  z_gbs

# %%
plot_10gids(l_gsb, df, df_pts432,'g', save=True, name='z_gsb')
# Out:
# save  z_gsb
